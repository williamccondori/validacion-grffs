# %%
# ==================== PARÁMETROS ====================
ESQUEMA = 'modalidad_acceso'
TABLA = 'Act_AutorizacionCamUsoActTieFinAgrPrePri'
# ==================== PARÁMETROS ====================

# %%
import geopandas
import pandas as pd
from sqlalchemy import create_engine, inspect
from geoalchemy2 import Geometry


engine = create_engine(f'postgresql://postgres:ficticio@200.48.19.4:9006/forestal_pre_actualizado')

def get_sql_query(tabla: str, esquema: str = 'public') -> str:
    sql = f"SELECT * FROM {esquema}.{tabla}"
    return sql

inspector = inspect(engine)
columns = inspector.get_columns(TABLA, schema=ESQUEMA)
df_table = pd.DataFrame(columns)

df_table
# Out:
#       name                     type  nullable  \
# 0       id                   BIGINT     False
# 1   TIPAUT            NUMERIC(5, 0)     False
# 2   NUMAUT              VARCHAR(50)     False
# 3   NOMTIT             VARCHAR(255)     False
# 4   NOMREL             VARCHAR(255)      True
# 5   NUMRUC              VARCHAR(11)     False
# 6   TIPDOC            NUMERIC(1, 0)     False
# 7   NRODOC              VARCHAR(10)     False
# 8   DOCTIT             VARCHAR(100)      True
# 9   CODCAT              VARCHAR(15)      True
# 10  SECTOR             VARCHAR(100)      True
# 11  SUPSIG           NUMERIC(10, 4)     False
# 12  SUPSOL           NUMERIC(10, 4)      True
# 13  SUPTOT           NUMERIC(10, 4)      True
# 14  SUPTIT           NUMERIC(10, 4)      True
# 15  NOMDIS             VARCHAR(150)     False
# 16  NOMPRO             VARCHAR(150)     False
# 17  NOMDEP               VARCHAR(2)     False
# 18  AUTFOR            NUMERIC(2, 0)     False
# ...
