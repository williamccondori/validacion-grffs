# %%
# PARÁMETROS
# ==================== PARÁMETROS ====================
ESQUEMA = 'manejo_forestal'
TABLA = 'DivAdmBos_Arbol'
# ==================== PARÁMETROS ====================

BASE_DE_DATOS = 'forestal_pre_actualizado'

# %%
import geopandas
import pandas as pd
from sqlalchemy import create_engine, inspect
from geoalchemy2 import Geometry


engine = create_engine(f'postgresql://postgres:ficticio@200.48.19.4:9006/{BASE_DE_DATOS}')

def get_sql_query(tabla: str, esquema: str = 'public') -> str:
    sql = f"SELECT * FROM {esquema}.{tabla}"
    return sql

# %% [markdown]
# # BASE DE DATOS

# %%
inspector = inspect(engine)
columns = inspector.get_columns(TABLA, schema=ESQUEMA)
df_table = pd.DataFrame(columns)
df_table
# Out:
#       name                   type  nullable  \
# 0       id                 BIGINT     False
# 1   NUMARB          NUMERIC(5, 0)     False
# 2    NUMUT          NUMERIC(3, 0)     False
# 3    NUMPC            VARCHAR(10)     False
# 4   NUMBLO            VARCHAR(10)      True
# 5   NUMFAJ          NUMERIC(1, 0)      True
# 6   CODARB            VARCHAR(50)      True
# 7   TIPOTH          NUMERIC(1, 0)     False
# 8   NROTTH           VARCHAR(100)     False
# 9   CODESP             VARCHAR(8)     False
# 10  NOMCOM           VARCHAR(100)     False
# 11  NOMCIE           VARCHAR(100)     False
# 12  FAMILI           VARCHAR(100)     False
# 13  GRUPOC           VARCHAR(100)     False
# 14  COORES         NUMERIC(10, 4)     False
# 15  COORNO         NUMERIC(11, 4)     False
# 16  CALFUS          NUMERIC(1, 0)     False
# 17  CONDIC          NUMERIC(1, 0)     False
# 18  CONDSA          NUMERIC(1, 0)     False
# 19   CITES          NUMERIC(1, 0)     False
# ...
